# %% [markdown]
# # Import
# - 2024-05-18
# - Language check on Getty ULAN data acquired via SPARQL-endpoint
# - V. Martens

# %% [markdown]
# ## Import packages

# %%
# handling jsons
import json
from json.decoder import JSONDecodeError

# spell check module
import language_tool_python

# creating time stamps
# from datetime import datetime
import time

# importing files
import glob
import os

# progress bar
from tqdm.notebook import tqdm

# regex module
import re

# for multi-threading
from concurrent import futures
from concurrent.futures import ThreadPoolExecutor
import multiprocessing as mp

# data wrangling
import pandas as pd

# back up files
import pickle

# check for western spellings
from alphabet_detector import AlphabetDetector

# spacy lang detect
import spacy
from spacy.language import Language
from spacy_langdetect import LanguageDetector

# preferences
# adjust pandas to show all cols
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Import data

# %%
# load lod-query from getty_ulan_sparql_endpoint script
# %store -r results_df

# to create a more standardized naming
df_results = results_df.copy()

results_df.shape
# Out:
# (12983, 8)

# %% [markdown]
# ## Constants

# %%
# create back up filename for a pickle
time_stamp = time.strftime('%Y%m%d-%H%M%S')
filename_df_errors = f'{time_stamp}_df_errors_aat.pickle'

# create back up filename for a pickle
time_stamp = time.strftime('%Y%m%d-%H%M%S')
filename_df_lod_results = f'{time_stamp}_df_lod_results_aat.pickle'

# create back up filename for a pickle
time_stamp = time.strftime('%Y%m%d-%H%M%S')
filename_excel_export = f'{time_stamp}_found_typos_AAT.xlsx'

print(f"{filename_df_errors}, {filename_df_lod_results}, {filename_excel_export}")
# Out:
# 20240531-114624_df_errors_aat.pickle, 20240531-114624_df_lod_results_aat.pickle, 20240531-114624_found_typos_AAT.xlsx

# %% [markdown]
# ## Import functions

# %%
@Language.factory('language_detector')
def language_detector(nlp, name):
    return LanguageDetector()

def check_df_row(df, col, i):
    '''
    '''
    dict_source_matches = {}
    try:
        matches = tool.check(df[col].iloc[i])
        dict_source_matches[df['Subject.value'].iloc[i]] = matches 
        return dict_source_matches
    except (JSONDecodeError, NameError) as e:
        return dict_source_matches[df['Subject.value'].iloc[i]] == 'na'
        print(e, df['Subject.value'].iloc[i])
    
    
def parse_list_of_jsons(json_list: list) -> pd.DataFrame():
    '''doc string'''
    df_errors = pd.DataFrame()

    for item in json_list:

        for k, v in item.items():
            source = k 

            for item in (v):

                df_error = pd.DataFrame(
                    (
                             source,
                             item.ruleId,
                             item.message,
                             item.replacements,
                             item.offsetInContext,
                             item.context,
                             item.offset,
                             item.errorLength,
                             item.category,
                             item.ruleIssueType,
                             item.sentence,
                             item.context[item.offsetInContext:int(item.offsetInContext + item.errorLength)],
                            )
                ).T

                df_errors = pd.concat([df_errors, df_error])

    df_errors = df_errors.rename(columns={
              0 : "url",
              1 : 'ruleId',
              2 : 'message', 
              3 : 'replacements',
              4 : 'offsetInContext',
              5 : 'context',
              6 : 'offset', 
              7 : 'errorLength',
              8 : 'category', 
              9 : 'ruleIssueType', 
              10 : 'sentence',
              11 : 'misspelledWord'})          

    return df_errors

def load_latest_file(filepath:str) -> str:
    '''args: string with filepath
    returns: latest file'''
    list_of_files = glob.glob(filepath)
    latest_file = max(list_of_files, key=os.path.getctime)
    print(latest_file)
    return latest_file

def create_aat_weblink(string:str) -> str:
    '''from a lod-url creates a regular ulan webpage link
    args: ulan lod landing page
    returns: regular human readable webpage
    '''
    aat_regex = re.compile('\d+')
    match_class_object = re.search(aat_regex, string)
    aat_id = match_class_object.group(0)
    return f"https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid={aat_id}"

def check_for_western_chars(string):
    try:
        valids = re.match(r"[A-Za-z-]+", string).group(0)
        return valids
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 @Language.factory('language_detector')
#       2 def language_detector(nlp, name):
#       3     return LanguageDetector()
#       5 def check_df_row(df, col, i):
#
# File ~\miniconda3\envs\getty_ulan\Lib\site-packages\spacy\language.py:518, in Language.factory.<locals>.add_factory(factory_func)
#     514     if not util.is_same_func(factory_func, existing_func):
#     515         err = Errors.E004.format(
#     516             name=name, func=existing_func, new_func=factory_func
#     517         )
# --> 518         raise ValueError(err)
#     520 arg_names = util.get_arg_names(factory_func)
#     521 if "nlp" not in arg_names or "name" not in arg_names:
#
# ValueError: [E004] Can't set up pipeline component: a factory for 'language_detector' already exists. Existing factory: <function language_detector at 0x0000020F99DCFBA0>. New factory: <function language_detector at 0x0000020F99EB39C0>

# %% [markdown]
# # Manipulate data

# %%
cpu_count = mp.cpu_count()
cpu_count

# %%
results_df = results_df[(results_df['ScopeNote.value'].notnull())]
results_df.shape

# %%
results_df.head()

# %%
# %%time

from tqdm import tqdm

# instance of language_tool_python
tool = language_tool_python.LanguageTool('en-US')

# Start pool
thread_pool = ThreadPoolExecutor(max_workers=cpu_count, thread_name_prefix = 'Thread')

# reate futures
futures = [thread_pool.submit(check_df_row, results_df, 'ScopeNote.value', i) for i in tqdm(range(len(results_df)), total=len(results_df), desc='building futures')]

# submit tasks
results = [future.result() for future in tqdm(futures, total=len(futures), desc='spell check data')]

# # Changed the func to add a df[col], to make it more compatible
# # instance of language_tool_python
# tool = language_tool_python.LanguageTool('en-US')

# # Start pool
# thread_pool = ThreadPoolExecutor(max_workers=cpu_count, thread_name_prefix = 'Thread')

# # reate futures
# futures = [thread_pool.submit(check_df_row, results_df, i) for i in tqdm(range(len(results_df)) , total=len(results_df), desc='building futures')]

# # submit tasks
# results = [future.result() for future in tqdm(futures, total=len(futures), desc='spell check data')]

# results = []
# for future in tqdm(futures, total=len(futures), desc='spell check data'):
#     try:
#         results.append(future.result())
#     except (JSONDecodeError, NameError) as e:
#         print(e)
#         pass

# # close tool
# tool.close()

# %%
df_errors = parse_list_of_jsons(results)

# %%
df_errors.head(5)

# %% [markdown]
# # Back up as a pickle

# %% [markdown]
# ##  Write

# %%
with open(f'data_dumps/{filename_df_errors}', 'wb') as handle:
    pickle.dump(df_errors, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open(f'data_dumps/{filename_df_lod_results}', 'wb') as handle:
    pickle.dump(results_df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Load

# %%
latest_picke_file = load_latest_file('data_dumps/*lod_results_aat.pickle')

# Open the file in binary mode
with open(latest_picke_file, 'rb') as file:
      
    # Call load method to deserialze
    df_lod_results_backup = pickle.load(file)
    
df_lod_results_backup.shape
# Out:
# data_dumps\20240530-221803_df_lod_results_aat.pickle
# (10242, 8)

# %%
latest_picke_file = load_latest_file('data_dumps/*errors_aat.pickle')

# Open the file in binary mode
with open(latest_picke_file, 'rb') as file:
      
    # Call load method to deserialze
    df_error_backup = pickle.load(file)
    
df_error_backup.shape
# Out:
# data_dumps\20240530-221803_df_errors_aat.pickle
# (5759, 12)

# %% [markdown]
# # Manipulate data

# %%
# creates human readable ulan link, based on lod link
df_error_backup['url_aat'] = df_error_backup['url'].apply(create_aat_weblink)

# %%
df_error_backup.head(1)
# Out:
#                                     url                 ruleId  \
# 0  http://vocab.getty.edu/aat/300266528  MORFOLOGIK_RULE_EN_US
#
#                             message  \
# 0  Possible spelling mistake found.
#
#                                   replacements offsetInContext  \
# 0  [Heart, Heat, Hera, Herein, He rat, Her at]              29
#
#                                                                          context  \
# 0  Persian wool carpets made in Herat, characterized by a wine red field colo...
#
#   offset errorLength category ruleIssueType  \
# 0     29           5    TYPOS   misspelling
#
#                                                                                                                                                           sentence  \
# 0  Persian wool carpets made in Herat, characterized by a wine red field color, and a border of clear emerald green and asymmetrical knotting; often made of silk.
#
#   misspelledWord  \
# 0          Herat
#
#                                                                               url_aat
# 0  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300266528

# %% [markdown]
# # Filter out spelling mistakes

# %% [markdown]
# ## Punctuation and whitespaces

# %%
# filter out punctuation errors
df_punctuation = df_error_backup[(df_error_backup['ruleId'] == 'UPPERCASE_SENTENCE_START') | 
                              (df_error_backup['ruleId'] == 'COMMA_PARENTHESIS_WHITESPACE') |
                              (df_error_backup['ruleId'] == 'WHITESPACE_RULE')]

df_error_backup = df_error_backup[(df_error_backup['ruleId'] != 'UPPERCASE_SENTENCE_START') &
                                  (df_error_backup['ruleId'] != 'COMMA_PARENTHESIS_WHITESPACE') & 
                                  (df_error_backup['ruleId'] != 'WHITESPACE_RULE')]

# %% [markdown]
# ## Check for non-Western typescripts

# %%
ad = AlphabetDetector()
df_error_backup['western_typo'] = df_error_backup['misspelledWord'].apply(lambda x: ad.is_latin(x))

print(f"non-western chars: {df_error_backup[(df_error_backup['western_typo'] == False )].shape[0]}")
df_error_backup = df_error_backup[(df_error_backup['western_typo'] == True )]

del df_error_backup['western_typo']
# Out:
# non-western chars: 2

# %% [markdown]
# ## Lang detect Spacy

# %%
nlp = spacy.load("en_core_web_lg")
nlp.max_length = 2000000
nlp.add_pipe('language_detector', last=True)

# initiate master df
df_spacies = pd.DataFrame()

# run over words
for item in tqdm(df_error_backup['misspelledWord'].tolist()):
    
    # store data in doc
    doc = nlp(str(item))
    detect_language = doc._.language

    # cast and store results into variable
    word = str(doc)
    language = str(detect_language['language'])
    score =  float(detect_language['score'])

    # add to df
    df_spacy = pd.DataFrame((word, language, score)).T
    df_spacies = pd.concat([df_spacy, df_spacies])

# manipulate all spacy results
df_spacies = (df_spacies
             .rename(columns={0: 'word',
                              1: 'language',
                              2: 'score'})
             .sort_values('score' ,ascending=False)
             .groupby(by=['word', 'language'])
             .first()
             .reset_index())

# subset false hits
df_spacies = df_spacies[(df_spacies['word'].str.len() > 3)]

# merge back with main dataset
df_error_backup = pd.merge(df_error_backup, df_spacies, left_on='misspelledWord', right_on='word', how='left')
# Out:
#   0%|          | 0/6043 [00:00<?, ?it/s]

# %% [markdown]
# # Check for language

# %%
# subsets chars from non western chars
df_error_backup['western_chars'] = df_error_backup['misspelledWord'].apply(check_for_western_chars)

# see if length is equal otherwise drop non-western chars
df_error_backup_test =  df_error_backup[(df_error_backup['western_chars'].str.len() == df_error_backup['misspelledWord'].str.len())]

# %% [markdown]
# # Check for entities

# %%
# run spacy on trained name data
nlp = spacy.load("en_core_web_lg")

entity_list = []

# run over annotations
for i in tqdm(df_error_backup_test['misspelledWord'].tolist()):
    # store data in doc
    doc = nlp(str(i))
    
    # retrieve entities from doc and ad it to a list
    for entity in doc.ents:
#         print(entity.text, entity.label_)
        entity_list.append((i, entity.text, entity.label_))
    
# untuple the list    
untupled = pd.DataFrame([[y for y in  x] for x in entity_list])

# add col names
untupled = untupled.rename(columns={0:'text',
                                    1:'person',
                                    2:'entity_label'})
# Out:
#   0%|          | 0/4533 [00:00<?, ?it/s]

# %%
false_positives = list(set(untupled['person'].tolist()))

false_positives = [item for item in false_positives if item != 'Scandanavian']

# %%
dftest = df_error_backup_test[(~df_error_backup_test['misspelledWord'].isin(false_positives)) & 
                              (df_error_backup_test['language'] == 'en')]

# %%
dftest.head(50)
# Out:
#                                       url                      ruleId  \
# 13   http://vocab.getty.edu/aat/300446210       MORFOLOGIK_RULE_EN_US
# 24   http://vocab.getty.edu/aat/300446758       MORFOLOGIK_RULE_EN_US
# 32   http://vocab.getty.edu/aat/300446212       MORFOLOGIK_RULE_EN_US
# 33   http://vocab.getty.edu/aat/300446212       MORFOLOGIK_RULE_EN_US
# 55   http://vocab.getty.edu/aat/300446753       MORFOLOGIK_RULE_EN_US
# 56   http://vocab.getty.edu/aat/300446753       MORFOLOGIK_RULE_EN_US
# 60   http://vocab.getty.edu/aat/300446200     EN_COMPOUNDS_CROSS_BARS
# 68   http://vocab.getty.edu/aat/300446759       MORFOLOGIK_RULE_EN_US
# 70   http://vocab.getty.edu/aat/300447075       MORFOLOGIK_RULE_EN_US
# 77   http://vocab.getty.edu/aat/300447075       MORFOLOGIK_RULE_EN_US
# 104  http://vocab.getty.edu/aat/300417723       MORFOLOGIK_RULE_EN_US
# 115  http://vocab.getty.edu/aat/300419421       MORFOLOGIK_RULE_EN_US
# 116  http://vocab.getty.edu/aat/300449152       MORFOLOGIK_RULE_EN_US
# 121  http://vocab.getty.edu/aat/300430606       MORFOLOGIK_RULE_EN_US
# 137  http://vocab.getty.edu/aat/300445554       MORFOLOGIK_RULE_EN_US
# 227  http://vocab.getty.edu/aat/300380075       MORFOLOGIK_RULE_EN_US
# 229  http://vocab.getty.edu/aat/300380075       MORFOLOGIK_RULE_EN_US
# 230  http://vocab.getty.edu/aat/300435483       MORFOLOGIK_RULE_EN_US
# 233  http://vocab.getty.edu/aat/300435483       MORFOLOGIK_RULE_EN_US
# 237  http://vocab.getty.edu/aat/300375655       MORFOLOGIK_RULE_EN_US
# 256  http://vocab.getty.edu/aat/300389646       MORFOLOGIK_RULE_EN_US
# 280  http://vocab.getty.edu/aat/300444063       MORFOLOGIK_RULE_EN_US
# 300  http://vocab.getty.edu/aat/300446216       MORFOLOGIK_RULE_EN_US
# 301  http://vocab.getty.edu/aat/300447042       MORFOLOGIK_RULE_EN_US
# 307  http://vocab.getty.edu/aat/300447035       MORFOLOGIK_RULE_EN_US
# 331  http://vocab.getty.edu/aat/300065033  EN_COMPOUNDS_FREE_STANDING
# 336  http://vocab.getty.edu/aat/300266453       MORFOLOGIK_RULE_EN_US
# 376  http://vocab.getty.edu/aat/300012941       MORFOLOGIK_RULE_EN_US
# 404  http://vocab.getty.edu/aat/300265089       MORFOLOGIK_RULE_EN_US
# 406  http://vocab.getty.edu/aat/300411370       MORFOLOGIK_RULE_EN_US
# 407  http://vocab.getty.edu/aat/300239112       MORFOLOGIK_RULE_EN_US
# 473  http://vocab.getty.edu/aat/300386864       MORFOLOGIK_RULE_EN_US
# 474  http://vocab.getty.edu/aat/300386864       MORFOLOGIK_RULE_EN_US
# 477  http://vocab.getty.edu/aat/300411731         SENTENCE_WHITESPACE
# 484  http://vocab.getty.edu/aat/300224972       MORFOLOGIK_RULE_EN_US
# 485  http://vocab.getty.edu/aat/300203978       MORFOLOGIK_RULE_EN_US
# 486  http://vocab.getty.edu/aat/300225006       MORFOLOGIK_RULE_EN_US
# 494  http://vocab.getty.edu/aat/300225146       MORFOLOGIK_RULE_EN_US
# 499  http://vocab.getty.edu/aat/300045514       MORFOLOGIK_RULE_EN_US
# 500  http://vocab.getty.edu/aat/300012976       MORFOLOGIK_RULE_EN_US
# 503  http://vocab.getty.edu/aat/300263203       MORFOLOGIK_RULE_EN_US
# 508  http://vocab.getty.edu/aat/300263589       MORFOLOGIK_RULE_EN_US
# 509  http://vocab.getty.edu/aat/300263589       MORFOLOGIK_RULE_EN_US
# 526  http://vocab.getty.edu/aat/300036777       MORFOLOGIK_RULE_EN_US
# 532  http://vocab.getty.edu/aat/300391266       MORFOLOGIK_RULE_EN_US
# 536  http://vocab.getty.edu/aat/300211038   EN_COMPOUNDS_HAND_WRITTEN
# 544  http://vocab.getty.edu/aat/300233387       MORFOLOGIK_RULE_EN_US
# 547  http://vocab.getty.edu/aat/300233843       MORFOLOGIK_RULE_EN_US
# 550  http://vocab.getty.edu/aat/300200661   EN_COMPOUNDS_HAND_WRITTEN
# 554  http://vocab.getty.edu/aat/300380051       MORFOLOGIK_RULE_EN_US
#
#                                                         message  \
# 13   Possible spelling mistake. ‘mouldings’ is British English.
# 24    Possible spelling mistake. ‘moulding’ is British English.
# 32                             Possible spelling mistake found.
# 33                             Possible spelling mistake found.
# 55    Possible spelling mistake. ‘moulding’ is British English.
# 56    Possible spelling mistake. ‘moulding’ is British English.
# 60                        This word is normally spelled as one.
# 68    Possible spelling mistake. ‘moulding’ is British English.
# 70    Possible spelling mistake. ‘moulding’ is British English.
# 77    Possible spelling mistake. ‘moulding’ is British English.
# 104                            Possible spelling mistake found.
# 115                            Possible spelling mistake found.
# 116                            Possible spelling mistake found.
# 121                            Possible spelling mistake found.
# 137                            Possible spelling mistake found.
# 227                            Possible spelling mistake found.
# 229                            Possible spelling mistake found.
# 230                            Possible spelling mistake found.
# 233                            Possible spelling mistake found.
# 237                            Possible spelling mistake found.
# 256                            Possible spelling mistake found.
# 280                            Possible spelling mistake found.
# 300  Possible spelling mistake. ‘mouldings’ is British English.
# 301                            Possible spelling mistake found.
# 307                            Possible spelling mistake found.
# 331                       This word is normally spelled as one.
# 336                            Possible spelling mistake found.
# 376                            Possible spelling mistake found.
# 404                            Possible spelling mistake found.
# 406                            Possible spelling mistake found.
# 407                            Possible spelling mistake found.
# 473                            Possible spelling mistake found.
# 474                            Possible spelling mistake found.
# 477                              Add a space between sentences.
# 484                            Possible spelling mistake found.
# 485                            Possible spelling mistake found.
# 486                            Possible spelling mistake found.
# 494                            Possible spelling mistake found.
# 499                            Possible spelling mistake found.
# 500                            Possible spelling mistake found.
# 503                            Possible spelling mistake found.
# 508                            Possible spelling mistake found.
# 509                            Possible spelling mistake found.
# 526                            Possible spelling mistake found.
# 532                            Possible spelling mistake found.
# 536                       This word is normally spelled as one.
# 544                            Possible spelling mistake found.
# 547  Possible spelling mistake. ‘mouldings’ is British English.
# 550                       This word is normally spelled as one.
# 554                            Possible spelling mistake found.
#
#                                                                                replacements  \
# 13                                                                               [moldings]
# 24                                                                                [molding]
# 32                                                                        [Jataka-buttress]
# 33                                                                          [Reith, rat ha]
# 55                                                                                [molding]
# 56                                                                                [molding]
# 60                                                                              [crossbars]
# 68                                                                                [molding]
# 70                                                                                [molding]
# 77                                                                                [molding]
# 104                                                                     [funeral, funerary]
# 115                                                                                      []
# 116                                                                                      []
# 121                                                    [Chariot, Charcot, Harlot, Char lot]
# 137                                                        [clothing, col thing, colt hing]
# 227                                              [cyclohexane, cyclohexanol, cyclohexanols]
# 229                                              [cyclohexane, cyclohexanol, cyclohexanols]
# 230                                                                             [threshold]
# 233                                                                             [threshold]
# 237                                                           [addition, edition, audition]
# 256  [best, next, text, Best, beat, belt, bent, bet, Bert, beet, ext, BEST, BET, BEX, sext]
# 280                                                                            [liturgical]
# 300                                                                              [moldings]
# 301                                                                         [Reith, rat ha]
# 307                                                                           [pith-course]
# 331                                                                          [freestanding]
# 336                                                                            [methylated]
# 376                       [Parthenon, Pantheism, Ruthenium, Arrhenius, Paramecium, Rhenium]
# 404                                                                    [airwaves, air wave]
# 406                                                                          [crew members]
# 407                                                   [affection, affectionate, affections]
# 473                                                                           [in painting]
# 474                                                                           [in painting]
# 477                                                                                [ These]
# 484                                                                        [breech loading]
# 485                                                                           [smooth bore]
# 486                                                                        [breech loading]
# 494                                    [surfaces, enhances, seaplanes, snaffles, anaphases]
# 499                                                                                      []
# 500                                              [asphalt, asphalted, asphalting, asphalts]
# 503                                                              [thought, through, throat]
# 508                                                                      [Roxbury, Rexburg]
# 509                                                                      [Roxbury, Rexburg]
# 526                                           [inarticulate, unarticulated, in articulated]
# 532                                                              [Chris males, Chrism ales]
# 536                                                                           [handwritten]
# 544                                                                          [crisscrossed]
# 547                                                                              [moldings]
# 550                                                                           [handwritten]
# 554                                                                            [acetylated]
#
#     offsetInContext  \
# 13               43
# 24               38
# 32               43
# 33               43
# 55               30
# 56               43
# 60               43
# 68               33
# 70               35
# 77               43
# 104              43
# 115              43
# 116              43
# 121              43
# 137              43
# 227              43
# 229              43
# 230              12
# 233              43
# 237              29
# 256              43
# 280              43
# 300              43
# 301              34
# 307              26
# 331              43
# 336              43
# 376              43
# 404              43
# 406              43
# 407              43
# 473              43
# 474              43
# 477              43
# 484              14
# 485              43
# 486              43
# 494              43
# 499              43
# 500              43
# 503              43
# 508              43
# 509              43
# 526              43
# 532              43
# 536              43
# 544              43
# 547              43
# 550              43
# 554              16
#
#                                                                                                     context  \
# 13                                                    ...cture, a vēdībhadra upapīṭha having six mouldings.
# 24                                       In Indian architecture, a knife-edged moulding in a base; karṇaka.
# 32   ...chitecture, an acute-angled and pointed rathaka-buttress; pointed half-diamond shaped ratha in g...
# 33              ...a-buttress; pointed half-diamond shaped ratha in ground plan as well as in elevation....
# 55                                 A type of kaṇṭha, or recessed moulding; recessed moulding in adhiṣṭhāna.
# 56                                       ... kaṇṭha, or recessed moulding; recessed moulding in adhiṣṭhāna.
# 60         ...ed at the junctions of the uprights and cross-bars flower-segment (jālī design), jāla type...
# 68                                     In Indian architecture, a kumbha moulding with highly concave curve.
# 70                   In Indian architecture, a recessed moulding (antarita) with patti-band above; often...
# 77                                               ...ra and vyāla figures; kaṇṭha with prati moulding above.
# 104           ...l and other objects. Prime examples are funeary bundles of the indigenous cultures of t...
# 115   ... on a transparent electrode coated with photoconductive material, the video signal being obtain...
# 116  ... of there being multiple ancestors in a polyhierarchical structure. The status of being the pref...
# 121           ...nal invention is credited to Julie Lynn Charlot, who sold pre-made skirts as well as pa...
# 137          ...), and occasionally appeared on women's colthing. The design may also be correlated with...
# 227     ... ketone resins, composed of polymerized cyclohexanone and/or methyl cyclohexanone and widely ...
# 229         ...polymerized cyclohexanone and/or methyl cyclohexanone and widely used for picture varnishes.
# 230                                       Long timber threshhold for a pātaka storehouse. By observing t...
# 233        ...rnamentation and decoration on a pataka threshhold, visitors to a tribe would be able to a...
# 237                         Cutback asphalt that has the adition of kerosene, which is less volatile tha...
# 256              ...ave adds a "Broadcast Audio Extension" (bext) with the minimum information necessary...
# 280       ...portable versions for occasions outside lithurgical services, such as visiting the sick. Th...
# 300                                                   ...pōtapālī topping above the prati-kaṇṭha mouldings.
# 301                              In Indian architecture, a pointed ratha of the jaṅghā section of the wall.
# 307                       In Indian architecture, a pitha-course showing humans engaged in manifold acti...
# 331     ...s found in Italian churches, often deep free-standing structures found particularly in mendic...
# 336      ...ll plant tissues. Pectin is composed of methoxylated galacturonic acids joined in long chain...
# 376        ...sinous latex of trees of the  Hevea and Parthenium genera. To prepare natural rubber, the ...
# 404           ...ial or fiber-optic cable (as opposed to airwave transmissions) to connected subscribers...
# 406                  ...and windows, which serve to accommodate crewmembers or passengers or ship material.
# 407       ...enter of an individual's domestic life, affectional relationships, and interests, together ...
# 473        ... between the original paper surface and inpainting media applied to compensate for loss or...
# 474                                       ...r layers allow for reversibility of the inpainting treatments.
# 477             ...receptions, and other ceremonial events.These consist of a dress coat with tails, a w...
# 484                                  Mechanisms on breechloading firearms featuring a manually operated ...
# 485                                        ...he path for the projectile. They may be smoothbore or rifled.
# 486     ...lt action, automatic, and semiautomatic breechloading rifles, machine guns, and submachine gu...
# 494                              ...rms holding the gunflint in flintlocks, snaphances, and miquelet locks.
# 499      ...at takes a brilliant polish and is used ornamentally, particularly in Victorian mourning jew...
# 500                                          ...sh hydrocarbon portion of asphalt, use "asphaltic bitumen."
# 503          ...nk amidships, that is raised or lowered throught the bottom of a vessel to provide stabi...
# 508         ...originally used for publications of the Roxburghe Club, an association of bibliophiles fo...
# 509                                                   ...and in 1812 and named after the Duke of Roxburghe.
# 526     ...and left vambraces; originally a single inarticulated curved plate in the 14th century, they ...
# 532        ...l cloths placed over a Christian altar. Chrismales altar cloths are impregnated with wax t...
# 536                                        ...cript typefaces based on Gothic cursive hand-written scripts.
# 544     ...anged in a decorative pattern, often in criss-crossed diagonal rows or spirals. Often seen in...
# 547                                                   ...regate plinths, sub-plinths, and column mouldings.
# 550                                        ...s and angular outlines, based on Gothic hand-written scripts.
# 554                                 Chitosan is the deacetylated form of chitin, the chief component in ...
#
#     offset errorLength    category ruleIssueType  \
# 13      57           9       TYPOS   misspelling
# 24      38           8       TYPOS   misspelling
# 32      52          16       TYPOS   misspelling
# 33      98           5       TYPOS   misspelling
# 55      30           8       TYPOS   misspelling
# 56      49           8       TYPOS   misspelling
# 60     112          10        MISC   misspelling
# 68      33           8       TYPOS   misspelling
# 70      35           8       TYPOS   misspelling
# 77     136           8       TYPOS   misspelling
# 104    137           7       TYPOS   misspelling
# 115    120          15       TYPOS   misspelling
# 116    216          16       TYPOS   misspelling
# 121    365           7       TYPOS   misspelling
# 137    310           8       TYPOS   misspelling
# 227    118          13       TYPOS   misspelling
# 229    146          13       TYPOS   misspelling
# 230     12          10       TYPOS   misspelling
# 233    113          10       TYPOS   misspelling
# 237     29           7       TYPOS   misspelling
# 256    227           4       TYPOS   misspelling
# 280    169          11       TYPOS   misspelling
# 300    100           9       TYPOS   misspelling
# 301     34           5       TYPOS   misspelling
# 307     26          12       TYPOS   misspelling
# 331     63          13        MISC   misspelling
# 336    125          12       TYPOS   misspelling
# 376     88          10       TYPOS   misspelling
# 404    112           7       TYPOS   misspelling
# 406    128          11       TYPOS   misspelling
# 407     71          11       TYPOS   misspelling
# 473    286          10       TYPOS   misspelling
# 474    396          10       TYPOS   misspelling
# 477    111           5  TYPOGRAPHY    whitespace
# 484     14          13       TYPOS   misspelling
# 485    192          10       TYPOS   misspelling
# 486    182          13       TYPOS   misspelling
# 494     54          10       TYPOS   misspelling
# 499     87          12       TYPOS   misspelling
# 500    211           9       TYPOS   misspelling
# 503     82           8       TYPOS   misspelling
# 508    262           9       TYPOS   misspelling
# 509    364           9       TYPOS   misspelling
# 526    149          13       TYPOS   misspelling
# 532     46          10       TYPOS   misspelling
# 536     50          12        MISC   misspelling
# 544    155          13       TYPOS   misspelling
# 547    159           9       TYPOS   misspelling
# 550     86          12        MISC   misspelling
# 554     16          12       TYPOS   misspelling
#
#                                                                                                                                                                                                                                                                                                                 sentence  \
# 13                                                                                                                                                                                                                                                   In Indian architecture, a vēdībhadra upapīṭha having six mouldings.
# 24                                                                                                                                                                                                                                                    In Indian architecture, a knife-edged moulding in a base; karṇaka.
# 32                                                                                                                                                                       In Indian architecture, an acute-angled and pointed rathaka-buttress; pointed half-diamond shaped ratha in ground plan as well as in elevation.
# 33                                                                                                                                                                       In Indian architecture, an acute-angled and pointed rathaka-buttress; pointed half-diamond shaped ratha in ground plan as well as in elevation.
# 55                                                                                                                                                                                                                                              A type of kaṇṭha, or recessed moulding; recessed moulding in adhiṣṭhāna.
# 56                                                                                                                                                                                                                                              A type of kaṇṭha, or recessed moulding; recessed moulding in adhiṣṭhāna.
# 60                                                                                                                                                   A jāla-screen with floral motif inserted in the orifices as well as carved at the junctions of the uprights and cross-bars flower-segment (jālī design), jāla type.
# 68                                                                                                                                                                                                                                                  In Indian architecture, a kumbha moulding with highly concave curve.
# 70                                                                                                                                                               In Indian architecture, a recessed moulding (antarita) with patti-band above; often bearing makara and vyāla figures; kaṇṭha with prati moulding above.
# 77                                                                                                                                                               In Indian architecture, a recessed moulding (antarita) with patti-band above; often bearing makara and vyāla figures; kaṇṭha with prati moulding above.
# 104                                                                                                                                                                                                                                       Prime examples are funeary bundles of the indigenous cultures of the Americas.
# 115             Small television camera tubes of a particular kind, in which the image is formed on a transparent electrode coated with photoconductive material, the video signal being obtained from the variation in the current flowing to or from this as it is scanned by a beam of (usually low-speed) electrons.
# 116                                                                  In a controlled vocabulary hierarchy, an ancestor record that provides a broader context for the record at hand, and that is defined as the primary ancestor record in the event of there being multiple ancestors in a polyhierarchical structure.
# 121                                                                                                                                                                                        The original invention is credited to Julie Lynn Charlot, who sold pre-made skirts as well as patterns for home construction.
# 137                                                                                                                                          As a prestigious design added to capes, it was typically worn by tlahtohqueh (rulers) and pipiltin (high ranking noble men), and occasionally appeared on women's colthing.
# 227                                                                                                               Any of a class of low molecular-weight synthetic varnish resins, also known as ketone resins, composed of polymerized cyclohexanone and/or methyl cyclohexanone and widely used for picture varnishes.
# 229                                                                                                               Any of a class of low molecular-weight synthetic varnish resins, also known as ketone resins, composed of polymerized cyclohexanone and/or methyl cyclohexanone and widely used for picture varnishes.
# 230                                                                                                                                                                                                                                                                      Long timber threshhold for a pātaka storehouse.
# 233                                                         By observing the carved ornamentation and decoration on a pataka threshhold, visitors to a tribe would be able to ascertain the chief's capacity to provide for his people and, therefore, the tribe's capacity and strength to protect and fend for itself.
# 237                                                                                                                                                                                 Cutback asphalt that has the adition of kerosene, which is less volatile than other additives, causing a slower evaporation process.
# 256                                                                                                                                           Built on the Microsoft WAVE audio file format, Broadcast Wave adds a "Broadcast Audio Extension" (bext) with the minimum information necessary for broadcast applications.
# 280                                                                                                                                                                                                    This term is extended to portable versions for occasions outside lithurgical services, such as visiting the sick.
# 300                                                                                                                                                                                                       In Indian architecture, an adhiṣṭhāna type with kapōta or kapōtapālī topping above the prati-kaṇṭha mouldings.
# 301                                                                                                                                                                                                                                           In Indian architecture, a pointed ratha of the jaṅghā section of the wall.
# 307                                                                                                                                                                                                                                In Indian architecture, a pitha-course showing humans engaged in manifold activities.
# 331                                                                                                                                       Distinctive rood screens found in Italian churches, often deep free-standing structures found particularly in mendicant churches and in many other monastic churches in Italy.
# 336                                                                                                                                                                                                                                         Pectin is composed of methoxylated galacturonic acids joined in long chains.
# 376                                                                                                                                                                                                           A natural hydrocarbon polymer formed from the resinous latex of trees of the  Hevea and Parthenium genera.
# 404                                                                                                                                                     Closed-circuit television system where programs are transmitted via coaxial or fiber-optic cable (as opposed to airwave transmissions) to connected subscribers.
# 406                                                                                                                                          Constructions on the upper decks of sailboats or motorboats, often equipped with a door and windows, which serve to accommodate crewmembers or passengers or ship material.
# 407                                                                                                                              A locale that constitutes the center of an individual's domestic life, affectional relationships, and interests, together with the feeling of comfort and satisfaction that it conveys.
# 473                                                                                                  In paper conservation, for example, a barrier layer is a thin film, such as gelatin or methylcellulose, deposited between the original paper surface and inpainting media applied to compensate for loss or damage.
# 474                                                                                                                                                                                                                                            Such barrier layers allow for reversibility of the inpainting treatments.
# 477                                                                                                                                These consist of a dress coat with tails, a waistcoat, a starched shirt with upstanding collar, a bow tie and a black pair of pants with the outer seam trimmed with satiny material.
# 484                   Mechanisms on breechloading firearms featuring a manually operated cylindrical bolt with an external lever which the shooter pulls back to open the breech and extract the empty case of a fired cartridge and pushes forward to push a fresh cartridge into firing position and close the breech.
# 485                                                                                                                                                                                                                                                                                    They may be smoothbore or rifled.
# 486                                                  Sliding breechblocks incorporating a firing pin, cartridge case extractor, and one or more lugs to lock them into firing position, found in bolt action, automatic, and semiautomatic breechloading rifles, machine guns, and submachine guns with blowback action.
# 494                                                                                                                                                                                                                                The striking arms holding the gunflint in flintlocks, snaphances, and miquelet locks.
# 499                                                                                                                                                                     A dense, black, semiprecious form of lignite that takes a brilliant polish and is used ornamentally, particularly in Victorian mourning jewelry.
# 500                                                                                                                                                                                                                                            For the blackish hydrocarbon portion of asphalt, use "asphaltic bitumen."
# 503                                                                                                                                                                              Pivoting boards mounted in a casing or trunk amidships, that is raised or lowered throught the bottom of a vessel to provide stability.
# 508                                                                                                                                    This type of binding was originally used for publications of the Roxburghe Club, an association of bibliophiles founded in England in 1812 and named after the Duke of Roxburghe.
# 509                                                                                                                                    This type of binding was originally used for publications of the Roxburghe Club, an association of bibliophiles founded in England in 1812 and named after the Duke of Roxburghe.
# 526  Plate armor to protect the elbow joints, attached by screws between the upper and lower cannons of the right and left vambraces; originally a single inarticulated curved plate in the 14th century, they evolved into a set of mobile lames loosely riveted together, remaining in use until the mid-17th century.
# 532                                                                                                                                                                                                                                           Chrismales altar cloths are impregnated with wax to make them impermeable.
# 536                                                                                                                                                                                                                                              Group of script typefaces based on Gothic cursive hand-written scripts.
# 544                                                                                                                   Embedded air pockets used as decoration of glass, comprising large, intentionally created air bubbles or tears, arranged in a decorative pattern, often in criss-crossed diagonal rows or spirals.
# 547                                                                                                                                                                                                                                               Column bases may aggregate plinths, sub-plinths, and column mouldings.
# 550                                                                                                                                                                                                          Group of typefaces characterized by heavy faces and angular outlines, based on Gothic hand-written scripts.
# 554                                                                                                                                                                                           Chitosan is the deacetylated form of chitin, the chief component in the exoskeletons of crustaceans, insects, and beetles.
#
#        misspelledWord  \
# 13          mouldings
# 24           moulding
# 32   rathaka-buttress
# 33              ratha
# 55           moulding
# 56           moulding
# 60         cross-bars
# 68           moulding
# 70           moulding
# 77           moulding
# 104           funeary
# 115   photoconductive
# 116  polyhierarchical
# 121           Charlot
# 137          colthing
# 227     cyclohexanone
# 229     cyclohexanone
# 230        threshhold
# 233        threshhold
# 237           adition
# 256              bext
# 280       lithurgical
# 300         mouldings
# 301             ratha
# 307      pitha-course
# 331     free-standing
# 336      methoxylated
# 376        Parthenium
# 404           airwave
# 406       crewmembers
# 407       affectional
# 473        inpainting
# 474        inpainting
# 477             These
# 484     breechloading
# 485        smoothbore
# 486     breechloading
# 494        snaphances
# 499      ornamentally
# 500         asphaltic
# 503          throught
# 508         Roxburghe
# 509         Roxburghe
# 526     inarticulated
# 532        Chrismales
# 536      hand-written
# 544     criss-crossed
# 547         mouldings
# 550      hand-written
# 554      deacetylated
#
#                                                                                 url_aat  \
# 13   https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446210
# 24   https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446758
# 32   https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446212
# 33   https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446212
# 55   https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446753
# 56   https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446753
# 60   https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446200
# 68   https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446759
# 70   https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300447075
# 77   https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300447075
# 104  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300417723
# 115  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300419421
# 116  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300449152
# 121  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300430606
# 137  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300445554
# 227  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300380075
# 229  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300380075
# 230  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300435483
# 233  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300435483
# 237  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300375655
# 256  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300389646
# 280  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300444063
# 300  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446216
# 301  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300447042
# 307  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300447035
# 331  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300065033
# 336  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300266453
# 376  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300012941
# 404  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300265089
# 406  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300411370
# 407  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300239112
# 473  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300386864
# 474  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300386864
# 477  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300411731
# 484  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300224972
# 485  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300203978
# 486  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300225006
# 494  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300225146
# 499  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300045514
# 500  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300012976
# 503  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300263203
# 508  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300263589
# 509  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300263589
# 526  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300036777
# 532  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300391266
# 536  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300211038
# 544  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300233387
# 547  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300233843
# 550  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300200661
# 554  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300380051
#
#                  word language     score              test     western_chars
# 13          mouldings       en  0.999997         mouldings         mouldings
# 24           moulding       en  0.999998          moulding          moulding
# 32   rathaka-buttress       en  0.571427  rathaka-buttress  rathaka-buttress
# 33              ratha       en  0.999997             ratha             ratha
# 55           moulding       en  0.999998          moulding          moulding
# 56           moulding       en  0.999998          moulding          moulding
# 60         cross-bars       en  0.999996        cross-bars        cross-bars
# 68           moulding       en  0.999998          moulding          moulding
# 70           moulding       en  0.999998          moulding          moulding
# 77           moulding       en  0.999998          moulding          moulding
# 104           funeary       en  0.714286           funeary           funeary
# 115   photoconductive       en  0.999994   photoconductive   photoconductive
# 116  polyhierarchical       en  0.999998  polyhierarchical  polyhierarchical
# 121           Charlot       en  0.999993           Charlot           Charlot
# 137          colthing       en  0.999997          colthing          colthing
# 227     cyclohexanone       en  0.571429     cyclohexanone     cyclohexanone
# 229     cyclohexanone       en  0.571429     cyclohexanone     cyclohexanone
# 230        threshhold       en  0.999999        threshhold        threshhold
# 233        threshhold       en  0.999999        threshhold        threshhold
# 237           adition       en  0.571428           adition           adition
# 256              bext       en  0.999993              bext              bext
# 280       lithurgical       en  0.999997       lithurgical       lithurgical
# 300         mouldings       en  0.999997         mouldings         mouldings
# 301             ratha       en  0.999997             ratha             ratha
# 307      pitha-course       en  0.999998      pitha-course      pitha-course
# 331     free-standing       en  0.999998     free-standing     free-standing
# 336      methoxylated       en  0.999995      methoxylated      methoxylated
# 376        Parthenium       en  0.999996        Parthenium        Parthenium
# 404           airwave       en  0.999998           airwave           airwave
# 406       crewmembers       en  0.999997       crewmembers       crewmembers
# 407       affectional       en  0.999996       affectional       affectional
# 473        inpainting       en  0.999995        inpainting        inpainting
# 474        inpainting       en  0.999995        inpainting        inpainting
# 477             These       en  0.999994             These             These
# 484     breechloading       en  0.999998     breechloading     breechloading
# 485        smoothbore       en  0.999997        smoothbore        smoothbore
# 486     breechloading       en  0.999998     breechloading     breechloading
# 494        snaphances       en  0.979612        snaphances        snaphances
# 499      ornamentally       en  0.999998      ornamentally      ornamentally
# 500         asphaltic       en  0.999997         asphaltic         asphaltic
# 503          throught       en  0.999998          throught          throught
# 508         Roxburghe       en   0.85714         Roxburghe         Roxburghe
# 509         Roxburghe       en   0.85714         Roxburghe         Roxburghe
# 526     inarticulated       en  0.714283     inarticulated     inarticulated
# 532        Chrismales       en  0.999997        Chrismales        Chrismales
# 536      hand-written       en  0.999997      hand-written      hand-written
# 544     criss-crossed       en  0.714284     criss-crossed     criss-crossed
# 547         mouldings       en  0.999997         mouldings         mouldings
# 550      hand-written       en  0.999997      hand-written      hand-written
# 554      deacetylated       en   0.85714      deacetylated      deacetylated

# %%
dftest['misspelledWord'].value_counts()
# Out:
# misspelledWord
# moulding         43
# mouldings        13
# free-standing    13
# storey           10
# tiaowo            8
#                  ..
# esonarthex        1
# cromlech          1
# roll-moulding     1
# attatched         1
# Struthio          1
# Name: count, Length: 254, dtype: int64

# %%
df_error_backup_test[(df_error_backup_test['language'] == 'en')]
# Out:
#                                        url                 ruleId  \
# 13    http://vocab.getty.edu/aat/300446210  MORFOLOGIK_RULE_EN_US
# 24    http://vocab.getty.edu/aat/300446758  MORFOLOGIK_RULE_EN_US
# 32    http://vocab.getty.edu/aat/300446212  MORFOLOGIK_RULE_EN_US
# 33    http://vocab.getty.edu/aat/300446212  MORFOLOGIK_RULE_EN_US
# 55    http://vocab.getty.edu/aat/300446753  MORFOLOGIK_RULE_EN_US
# ...                                    ...                    ...
# 5922  http://vocab.getty.edu/aat/300389308  MORFOLOGIK_RULE_EN_US
# 5934  http://vocab.getty.edu/aat/300395469  MORFOLOGIK_RULE_EN_US
# 5942  http://vocab.getty.edu/aat/300445394  MORFOLOGIK_RULE_EN_US
# 6033  http://vocab.getty.edu/aat/300445065  MORFOLOGIK_RULE_EN_US
# 6038  http://vocab.getty.edu/aat/300445055  MORFOLOGIK_RULE_EN_US
#
#                                                          message  \
# 13    Possible spelling mistake. ‘mouldings’ is British English.
# 24     Possible spelling mistake. ‘moulding’ is British English.
# 32                              Possible spelling mistake found.
# 33                              Possible spelling mistake found.
# 55     Possible spelling mistake. ‘moulding’ is British English.
# ...                                                          ...
# 5922                            Possible spelling mistake found.
# 5934                            Possible spelling mistake found.
# 5942                            Possible spelling mistake found.
# 6033                            Possible spelling mistake found.
# 6038                            Possible spelling mistake found.
#
#             replacements offsetInContext  \
# 13            [moldings]              43
# 24             [molding]              38
# 32     [Jataka-buttress]              43
# 33       [Reith, rat ha]              43
# 55             [molding]              30
# ...                  ...             ...
# 5922       [Soho-Tswana]              31
# 5934  [Trevino, Treviño]              43
# 5942            [Strüth]              25
# 6033        [herbaceous]              43
# 6038            [Tecate]              43
#
#                                                                                                      context  \
# 13                                                     ...cture, a vēdībhadra upapīṭha having six mouldings.
# 24                                        In Indian architecture, a knife-edged moulding in a base; karṇaka.
# 32    ...chitecture, an acute-angled and pointed rathaka-buttress; pointed half-diamond shaped ratha in g...
# 33               ...a-buttress; pointed half-diamond shaped ratha in ground plan as well as in elevation....
# 55                                  A type of kaṇṭha, or recessed moulding; recessed moulding in adhiṣṭhāna.
# ...                                                                                                      ...
# 5922                                                     Southern Bantu language of the Sotho-Tswana people.
# 5934                      ...n Venice (Venetian), Verona (Veronese), Treviso (Trevisan), and Padua (Paduan).
# 5942                            Feathers of the ostrich (Struthio cemelus) used primarily in the adornmen...
# 6033        ...ng the material and color of turquoise, herbacious plants or grasses, as well as asterisms...
# 6038           ...four of them (calli, tochtli, acatl and tecpatl) were also used to designate the name o...
#
#      offset errorLength category ruleIssueType  \
# 13       57           9    TYPOS   misspelling
# 24       38           8    TYPOS   misspelling
# 32       52          16    TYPOS   misspelling
# 33       98           5    TYPOS   misspelling
# 55       30           8    TYPOS   misspelling
# ...     ...         ...      ...           ...
# 5922     31          12    TYPOS   misspelling
# 5934    134           7    TYPOS   misspelling
# 5942     25           8    TYPOS   misspelling
# 6033    191          10    TYPOS   misspelling
# 6038     86           7    TYPOS   misspelling
#
#                                                                                                                                                                                                                                                                               sentence  \
# 13                                                                                                                                                                                                                 In Indian architecture, a vēdībhadra upapīṭha having six mouldings.
# 24                                                                                                                                                                                                                  In Indian architecture, a knife-edged moulding in a base; karṇaka.
# 32                                                                                                                                     In Indian architecture, an acute-angled and pointed rathaka-buttress; pointed half-diamond shaped ratha in ground plan as well as in elevation.
# 33                                                                                                                                     In Indian architecture, an acute-angled and pointed rathaka-buttress; pointed half-diamond shaped ratha in ground plan as well as in elevation.
# 55                                                                                                                                                                                                            A type of kaṇṭha, or recessed moulding; recessed moulding in adhiṣṭhāna.
# ...                                                                                                                                                                                                                                                                                ...
# 5922                                                                                                                                                                                                                               Southern Bantu language of the Sotho-Tswana people.
# 5934                                                                                                                                                                  It includes the dialects spoken in Venice (Venetian), Verona (Veronese), Treviso (Trevisan), and Padua (Paduan).
# 5942                                                                                                                                                                              Feathers of the ostrich (Struthio cemelus) used primarily in the adornment of garments such as hats.
# 6033  A multivalent term referring to the solar year of 365 days counted in the xiuhpohualli (Nahua calendar) as well as a number of related concepts including the material and color of turquoise, herbacious plants or grasses, as well as asterisms such as comets and meteorites.
# 6038                                                 Among the twenty signs of the Nahua calendar, four of them (calli, tochtli, acatl and tecpatl) were also used to designate the name of the solar years of the xiuhpohualli (solar calendar of three hundred and sixty five days).
#
#         misspelledWord  \
# 13           mouldings
# 24            moulding
# 32    rathaka-buttress
# 33               ratha
# 55            moulding
# ...                ...
# 5922      Sotho-Tswana
# 5934           Treviso
# 5942          Struthio
# 6033        herbacious
# 6038           tecpatl
#
#                                                                                  url_aat  \
# 13    https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446210
# 24    https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446758
# 32    https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446212
# 33    https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446212
# 55    https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300446753
# ...                                                                                  ...
# 5922  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300389308
# 5934  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300395469
# 5942  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300445394
# 6033  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300445065
# 6038  https://www.getty.edu/vow/AATFullDisplay?find=&logic=AND&note=&subjectid=300445055
#
#                   word language     score              test     western_chars
# 13           mouldings       en  0.999997         mouldings         mouldings
# 24            moulding       en  0.999998          moulding          moulding
# 32    rathaka-buttress       en  0.571427  rathaka-buttress  rathaka-buttress
# 33               ratha       en  0.999997             ratha             ratha
# 55            moulding       en  0.999998          moulding          moulding
# ...                ...      ...       ...               ...               ...
# 5922      Sotho-Tswana       en  0.857141      Sotho-Tswana      Sotho-Tswana
# 5934           Treviso       en  0.857138           Treviso           Treviso
# 5942          Struthio       en  0.999996          Struthio          Struthio
# 6033        herbacious       en  0.999996        herbacious        herbacious
# 6038           tecpatl       en  0.724158           tecpatl           tecpatl
#
# [542 rows x 18 columns]

# %% [markdown]
# ## Filter out cities

# %%
df_spacies[(df_spacies['language'] != 'en')].sample(50)
# Out:
#                  word language     score
# 2283          odorant       pt  0.999995
# 496             Kyoga       so  0.999997
# 245            Digong       tl  0.999996
# 419     Indo-Malaysia       id  0.857141
# 1868        hindlimbs       sw  0.999999
# 2941         udumbara       id  0.999996
# 1186         avataras       sv   0.42857
# 949         Vaccinium       it  0.714261
# 2789    subsequent to       ca  0.999996
# 1590        diasporic       pt  0.571428
# 1794   general public       es  0.856357
# 2320      oversailing       da  0.713849
# 1097   alphasyllabary       tl  0.714283
# 2797            sulfo       ro  0.999997
# 258           Drāviḍa       lv  0.999998
# 614          Mēṣapāda       lv  0.999998
# 1668       endeavours       fr  0.999994
# 3098         yingshan       so  0.714284
# 1772       gaja-hasta       et  0.857141
# 1876          huagong       tl  0.999997
# 1221         beadwork       af  0.857141
# 286   Farbenindustrie       de  0.999995
# 1082        air space       lv  0.999997
# 458           Kannaḍa       fi  0.999996
# 2961         unroofed       cy   0.85714
# 3032     vṛttaspuṭita       fi  0.999996
# 1812           gongbu       tl  0.999996
# 3008       vinylidine       lt  0.999996
# 820           Servite       fi  0.857501
# 2328            padma       pt  0.714285
# 2743         spritual       it  0.857296
# 111         Benchlike       de  0.999998
# 2539          remains       fr  0.999995
# 1731          florida       es  0.999995
# 2179         miquelet       fr  0.999995
# 1368            cella       it  0.999998
# 2373       pedalboard       ro  0.571426
# 1348      caprolactam       es  0.999992
# 1245          bhadras       cy  0.714285
# 2045             kūṭa       lt  0.999998
# 483             Kokka       fi  0.999997
# 1986           kapilī       lv  0.999997
# 1445      consolidant       pt  0.999995
# 2776            stūpa       lv  0.999994
# 1051            acatl       ca  0.856929
# 713              Pili       tl  0.999999
# 3104           yuetai       fi  0.999995
# 667          Ottonian       it  0.999992
# 2958  uniform in size       ro  0.999996
# 601            Morman       ro  0.999993

# %%
df_error_backup[(df_error_backup['western_typo'] == False )]

# %%
df_punctuation.shape

# %%
# # filter out punctuation errors
# df_punctuation = df_error_backup[(df_error_backup['ruleId'] == 'UPPERCASE_SENTENCE_START') | 
#                               (df_error_backup['ruleId'] == 'COMMA_PARENTHESIS_WHITESPACE') |
#                               (df_error_backup['ruleId'] == 'WHITESPACE_RULE')]

# df_error_backup = df_error_backup[(df_error_backup['ruleId'] != 'UPPERCASE_SENTENCE_START') &
#                                   (df_error_backup['ruleId'] != 'COMMA_PARENTHESIS_WHITESPACE') & 
#                                   (df_error_backup['ruleId'] != 'WHITESPACE_RULE')]

# # 
# print(f"punctuation: {df_punctuation.shape}, \n errors_left: {df_error_backup.shape}, \n checked_errors: {df_checked_errors.shape}")

# %%
df_holland = results_df[(results_df['bio.value'].str.contains('Holland') == True)]

# creates human readable ulan link, based on lod link
df_holland['url_ulan'] = df_holland['x.value'].apply(create_ulan_weblink)

# the one errouneous holland
df_holland = df_holland[(df_holland['url_ulan'].str.contains('500256837') == True)]

# %%
# add cols to allign with other cols
df_holland['ruleId'] = 'PREFERRED SPELLING'
df_holland['message'] = 'Prefered spelling is the Netherlands.'
df_holland['replacements'] = ['The Netherlands']
df_holland['offsetInContext'] = 0
df_holland['context'] = df_holland['bio.value']
df_holland['offset'] = 0
df_holland['errorLength'] = 0
df_holland['category'] = 'PREFERRED SPELLING'
df_holland['ruleIssueType'] = 'typographical'
df_holland['sentence'] = df_holland['bio.value']
df_holland['misspelledWord'] = 'Holland'

# rename cols
df_holland = df_holland.rename(columns={'x.value':'url'})

# select cols
df_holland = df_holland[['url', 'ruleId', 'message', 'replacements', 'offsetInContext',
       'context', 'offset', 'errorLength', 'category', 'ruleIssueType',
       'sentence', 'misspelledWord', 'url_ulan']]

# %% [markdown]
# # Merge all found errors and create export

# %%
# merge
df_spell_check = pd.concat([df_checked_errors, df_punctuation, df_holland])

# select cols
df_spell_check = df_spell_check[['url', 
                                 'url_ulan', 
                                'sentence',
                                 'ruleId', 
                                 'message', 
                                 'replacements', 
                                 'offsetInContext',
#                                  'context', 
                                 'offset', 
                                 'errorLength', 
                                 'category', 
                                 'ruleIssueType',
                                 'misspelledWord'
                                ]]

# rename cols
df_spell_check = df_spell_check.rename(columns={'url' : 'url_lod'})

# reset index
df_spell_check = df_spell_check.reset_index().drop(columns='index')

# %% [markdown]
# # Export

# %%
filename_excel_export

# %%
df_spell_check.to_excel('data_dumps\\' + filename_excel_export, index=False)

# %% [markdown]
# # Check for similar names

# %%
# https://stackoverflow.com/questions/52631291/vectorizing-or-speeding-up-fuzzywuzzy-string-matching-on-pandas-column

import pandas as pd 
import numpy as np


# df = pd.DataFrame([['cliftonlarsonallen llp minneapolis MN'],
#         ['loeb and troper llp newyork NY'],
#         ["dauby o'connor and zaleski llc carmel IN"],
#         ['wegner cpas llp madison WI']],
#         columns=['org_name'])

name_vals = results_df['name.value'].to_list()

# name_vals = name_vals[0:10]

threshold = 90

def find_match(x):
    ''''''
    match = process.extract(x, name_vals, limit=2, scorer=fuzz.partial_token_sort_ratio)
#     match = match if match[1] > threshold else np.nan
    return match

# results_df['match_found'] = results_df['name.value'].progress_apply(find_match)

# %%
from fuzzywuzzy import process, fuzz

# %%
# %%timeit

# create list
name_vals = results_df['name.value'].to_list()

name_vals = name_vals[0:5]

#Create tuples of brand names, matched brand names, and the score
score_sort = [(x,) + i
             for x in tqdm(name_vals)
             for i in process.extract(x, name_vals, scorer=fuzz.token_sort_ratio)]

# %%
#Create a dataframe from the tuples
df_similarity = pd.DataFrame(score_sort, columns=['artist','match_sort','similarity_score'])

# df_similarity = df_similarity[(df_similarity['score_sort'] > 91) &
#                               (df_similarity['score_sort'] != 100)]

# # create back up filename for a pickle
# time_stamp = time.strftime('%Y%m%d-%H%M%S')
# filename_df_similarity = f'{time_stamp}_df_similarity.xlsx'

# # export
# df_similarity.to_excel('data_dumps\\' + filename_df_similarity, index=False)

# %% [markdown]
# # Other options for spell-checks

# %%
states = ['IA', 'KS', 'UT', 'VA', 'NC', 'NE', 'SD', 'AL', 'ID', 'FM', 'DE', 'AK', 'CT', 'PR', 'NM', 'MS', 'PW', 'CO', 'NJ', 'FL', 'MN', 'VI', 'NV', 'AZ', 'WI', 'ND', 'PA', 'OK', 'KY', 'RI', 'NH', 'MO', 'ME', 'VT', 'GA', 'GU', 'AS', 'NY', 'CA', 'HI', 'IL', 'TN', 'MA', 'OH', 'MD', 'MI', 'WY', 'WA', 'OR', 'MH', 'SC', 'IN', 'LA', 'MP', 'DC', 'MT', 'AR', 'WV', 'TX']
regex = re.compile(r'\b(' + '|'.join(states) + r')\b', re.IGNORECASE)

states2 = ['I.A.', 'K.S.', 'U.T.', 'V.A.', 'N.C.', 'N.E.', 'S.D.', 'A.L.', 'I.D.', 'F.M.', 'D.E.', 'A.K.', 'C.T.',
           'P.R.', 'N.M.', 'M.S.', 'P.W.', 'C.O.', 'N.J.', 'F.L.', 'M.N.', 'V.I.', 'N.V.', 'A.Z.', 'W.I.', 'N.D.', 
           'P.A.', 'O.K.', 'K.Y.', 'R.I.', 'N.H.', 'M.O.', 'M.E.', 'V.T.', 'G.A.', 'G.U.', 'A.S.', 'N.Y.', 'C.A.', 
           'H.I.', 'I.L.', 'T.N.', 'M.A.', 'O.H.', 'M.D.', 'M.I.', 'W.Y.', 'W.A.', 'O.R.', 'M.H.', 'S.C.', 'I.N.', 
           'L.A.', 'M.P.', 'D.C.', 'M.T.', 'A.R.', 'W.V.', 'T.X.']
regex2 = re.compile(r'\b(' + '|'.join(states) + r')\b', re.IGNORECASE)

# %%
def state_finder(string:str) -> list:
    ''''''
    states2 = []
#     states = ['IA', 'KS', 'UT', 'VA', 'NC', 'NE', 'SD', 'AL', 'ID', 'FM', 'DE', 'AK', 'CT', 'PR', 'NM', 'MS', 'PW', 
#               'CO', 'NJ', 'FL', 'MN', 'VI', 'NV', 'AZ', 'WI', 'ND', 'PA', 'OK', 'KY', 'RI', 'NH', 'MO', 'ME', 'VT', 
#               'GA', 'GU', 'AS', 'NY', 'CA', 'HI', 'IL', 'TN', 'MA', 'OH', 'MD', 'MI', 'WY', 'WA', 'OR', 'MH', 'SC', 
#               'IN', 'LA', 'MP', 'DC', 'MT', 'AR', 'WV', 'TX']

    states = ['I.A.', 'K.S.', 'U.T.', 'V.A.', 'N.C.', 'N.E.', 'S.D.', 'A.L.', 'I.D.', 'F.M.', 'D.E.', 'A.K.', 'C.T.',
           'P.R.', 'N.M.', 'M.S.', 'P.W.', 'C.O.', 'N.J.', 'F.L.', 'M.N.', 'V.I.', 'N.V.', 'A.Z.', 'W.I.', 'N.D.', 
           'P.A.', 'O.K.', 'K.Y.', 'R.I.', 'N.H.', 'M.O.', 'M.E.', 'V.T.', 'G.A.', 'G.U.', 'A.S.', 'N.Y.', 'C.A.', 
           'H.I.', 'I.L.', 'T.N.', 'M.A.', 'O.H.', 'M.D.', 'M.I.', 'W.Y.', 'W.A.', 'O.R.', 'M.H.', 'S.C.', 'I.N.', 
           'L.A.', 'M.P.', 'D.C.', 'M.T.', 'A.R.', 'W.V.', 'T.X.']                   
                  
    regex = re.compile(r'\b(' + '|'.join(states) + r')\b', re.IGNORECASE)

    try:
        string = str(string)
        states2 = re.findall(regex , string)
        return states2
    except:
        pass

# %%
tqdm.pandas(desc="power DataFrame 1M to 100 random int!")
results_df['test'] = results_df['bio.value'].progress_apply(state_finder)

# %%
results_df[(results_df['test'].str.len() > 2)]

# %%
results_df[
#     (results_df['bio.value'].str.contains('I.A.') == True) |
    (results_df['bio.value'].str.contains('Calif\.') == True) |
    (results_df['bio.value'].str.contains('CA') == True) |
    (results_df['bio.value'].str.contains('C\.A\.') == True) |
    (results_df['bio.value'].str.contains('California') == True)]
# (results_df['bio.value'].str.contains('K.S.') == True) |
# (results_df['bio.value'].str.contains('U.T.') == True) |
# (results_df['bio.value'].str.contains('V.A.') == True) |
# (results_df['bio.value'].str.contains('N.C.') == True) |
# (results_df['bio.value'].str.contains('N.E.') == True) |
# (results_df['bio.value'].str.contains('S.D.') == True) |
# (results_df['bio.value'].str.contains('A.L.') == True) |
# (results_df['bio.value'].str.contains('I.D.') == True) |
# (results_df['bio.value'].str.contains('F.M.') == True) |
# (results_df['bio.value'].str.contains('D.E.') == True) |
# (results_df['bio.value'].str.contains('A.K.') == True) |
# (results_df['bio.value'].str.contains('C.T.') == True) |
# (results_df['bio.value'].str.contains('P.R.') == True) |
# (results_df['bio.value'].str.contains('N.M.') == True) |
# (results_df['bio.value'].str.contains('M.S.') == True) |
# (results_df['bio.value'].str.contains('P.W.') == True) |
# (results_df['bio.value'].str.contains('C.O.') == True) |
# (results_df['bio.value'].str.contains('N.J.') == True) |
# (results_df['bio.value'].str.contains('F.L.') == True) |
# (results_df['bio.value'].str.contains('M.N.') == True) |
# (results_df['bio.value'].str.contains('V.I.') == True) |
# (results_df['bio.value'].str.contains('N.V.') == True) |
# (results_df['bio.value'].str.contains('A.Z.') == True) |
# (results_df['bio.value'].str.contains('W.I.') == True) |
# (results_df['bio.value'].str.contains('N.D.') == True) |
# (results_df['bio.value'].str.contains('P.A.') == True) |
# (results_df['bio.value'].str.contains('O.K.') == True) |
# (results_df['bio.value'].str.contains('K.Y.') == True) |
# (results_df['bio.value'].str.contains('R.I.') == True) |
# (results_df['bio.value'].str.contains('N.H.') == True) |
# (results_df['bio.value'].str.contains('M.O.') == True) |
# (results_df['bio.value'].str.contains('M.E.') == True) |
# (results_df['bio.value'].str.contains('V.T.') == True) |
# (results_df['bio.value'].str.contains('G.A.') == True) |
# (results_df['bio.value'].str.contains('G.U.') == True) |
# (results_df['bio.value'].str.contains('A.S.') == True) |
# (results_df['bio.value'].str.contains('N.Y.') == True) |
# (results_df['bio.value'].str.contains('C.A.') == True) |
# (results_df['bio.value'].str.contains('H.I.') == True) |
# (results_df['bio.value'].str.contains('I.L.') == True) |
# (results_df['bio.value'].str.contains('T.N.') == True) |
# (results_df['bio.value'].str.contains('M.A.') == True) |
# (results_df['bio.value'].str.contains('O.H.') == True) |
# (results_df['bio.value'].str.contains('M.D.') == True) |
# (results_df['bio.value'].str.contains('M.I.') == True) |
# (results_df['bio.value'].str.contains('W.Y.') == True) |
# (results_df['bio.value'].str.contains('W.A.') == True) |
# (results_df['bio.value'].str.contains('O.R.') == True) |
# (results_df['bio.value'].str.contains('M.H.') == True) |
# (results_df['bio.value'].str.contains('S.C.') == True) |
# (results_df['bio.value'].str.contains('I.N.') == True) |
# (results_df['bio.value'].str.contains('L.A.') == True) |
# (results_df['bio.value'].str.contains('M.P.') == True) |
# (results_df['bio.value'].str.contains('D.C.') == True) |
# (results_df['bio.value'].str.contains('M.T.') == True) |
# (results_df['bio.value'].str.contains('A.R.') == True) |
# (results_df['bio.value'].str.contains('W.V.') == True) |
# (results_df['bio.value'].str.contains('T.X.') == True)]

# %%
results_df[
#     (results_df
#             ['bio.value'].str.contains('Alabama') == True) | 
# (results_df['bio.value'].str.contains('Alaska') == True) | 
# (results_df['bio.value'].str.contains('Arizona') == True) | 
# (results_df['bio.value'].str.contains('Arkansas') == True) | 
# (results_df['bio.value'].str.contains('California') == True) | 
# (results_df['bio.value'].str.contains('Colorado') == True) | 
# (results_df['bio.value'].str.contains('Connecticut') == True) | 
# (results_df['bio.value'].str.contains('Delaware') == True) | 
# (results_df['bio.value'].str.contains('Florida') == True) | 
# (results_df['bio.value'].str.contains('Georgia') == True) | 
# (results_df['bio.value'].str.contains('Hawaii') == True) | 
# (results_df['bio.value'].str.contains('Idaho') == True) | 
# (results_df['bio.value'].str.contains('Illinois') == True) | 
# (results_df['bio.value'].str.contains('Indiana') == True) | 
# (results_df['bio.value'].str.contains('Iowa') == True) | 
# (results_df['bio.value'].str.contains('Kansas') == True) | 
# (results_df['bio.value'].str.contains('Kentucky') == True) | 
# (results_df['bio.value'].str.contains('Louisiana') == True) | 
# (results_df['bio.value'].str.contains('Maine') == True) | 
# (results_df['bio.value'].str.contains('Maryland') == True) | 
# (results_df['bio.value'].str.contains('Massachusetts') == True) | 
# (results_df['bio.value'].str.contains('Michigan') == True) | 
# (results_df['bio.value'].str.contains('Minnesota') == True) | 
# (results_df['bio.value'].str.contains('Mississippi') == True) | 
# (results_df['bio.value'].str.contains('Missouri') == True) | 
# (results_df['bio.value'].str.contains('Montana') == True) | 
# (results_df['bio.value'].str.contains('Nebraska') == True) | 
# (results_df['bio.value'].str.contains('Nevada') == True) | 
# (results_df['bio.value'].str.contains('New Hampshire') == True) | 
# (results_df['bio.value'].str.contains('New Jersey') == True) | 
# (results_df['bio.value'].str.contains('New Mexico') == True) | 
# (results_df['bio.value'].str.contains('New York') == True) | 
# (results_df['bio.value'].str.contains('North Carolina') == True) | 
# (results_df['bio.value'].str.contains('North Dakota') == True) | 
# (results_df['bio.value'].str.contains('Ohio') == True) | 
# (results_df['bio.value'].str.contains('Oklahoma') == True) | 
# (results_df['bio.value'].str.contains('Oregon') == True) | 
# (results_df['bio.value'].str.contains('Pennsylvania') == True) | 
# (results_df['bio.value'].str.contains('Rhode Island') == True) | 
# (results_df['bio.value'].str.contains('South Carolina') == True) | 
# (results_df['bio.value'].str.contains('South Dakota') == True) | 
# (results_df['bio.value'].str.contains('Tennessee') == True) | 
# (results_df['bio.value'].str.contains('Texas') == True) | 
# (results_df['bio.value'].str.contains('Utah') == True) | 
# (results_df['bio.value'].str.contains('Vermont') == True) | 
# (results_df['bio.value'].str.contains('Virginia') == True) | 
# (results_df['bio.value'].str.contains('Washington') == True) | 
# (results_df['bio.value'].str.contains('West Virginia') == True) | 
# (results_df['bio.value'].str.contains('Wisconsin') == True) | 
# (results_df['bio.value'].str.contains('Wyoming') == True) | 
# (results_df['bio.value'].str.contains('District of Columbia') == True) | 
# (results_df['bio.value'].str.contains('Guam') == True) | 
# (results_df['bio.value'].str.contains('Marshall Islands') == True) | 
# (results_df['bio.value'].str.contains('Northern Mariana Island') == True) | 
# (results_df['bio.value'].str.contains('Puerto Rico') == True) | 
# (results_df['bio.value'].str.contains('Virgin Islands') == True) | 
# (results_df['bio.value'].str.contains('AL') == True) | 
# (results_df['bio.value'].str.contains('AK') == True) | 
# (results_df['bio.value'].str.contains('AZ') == True) | 
# (results_df['bio.value'].str.contains('AR') == True) | 
# (results_df['bio.value'].str.contains('CA') == True) | 
# (results_df['bio.value'].str.contains('CO') == True) | 
# (results_df['bio.value'].str.contains('CT') == True) | 
# (results_df['bio.value'].str.contains('DE') == True) | 
# (results_df['bio.value'].str.contains('FL') == True) | 
# (results_df['bio.value'].str.contains('GA') == True) | 
# (results_df['bio.value'].str.contains('HI') == True) | 
# (results_df['bio.value'].str.contains('ID') == True) | 
# (results_df['bio.value'].str.contains('IL') == True) | 
# (results_df['bio.value'].str.contains('IN') == True) | 
# (results_df['bio.value'].str.contains('IA') == True) | 
# (results_df['bio.value'].str.contains('KS') == True) | 
# (results_df['bio.value'].str.contains('KY') == True) | 
# (results_df['bio.value'].str.contains('LA') == True) | 
# (results_df['bio.value'].str.contains('ME') == True) | 
# (results_df['bio.value'].str.contains('MD') == True) | 
# (results_df['bio.value'].str.contains('MA') == True) | 
# (results_df['bio.value'].str.contains('MI') == True) | 
# (results_df['bio.value'].str.contains('MN') == True) | 
# (results_df['bio.value'].str.contains('MS') == True) | 
# (results_df['bio.value'].str.contains('MO') == True) | 
# (results_df['bio.value'].str.contains('MT') == True) | 
# (results_df['bio.value'].str.contains('NE') == True) | 
# (results_df['bio.value'].str.contains('NV') == True) | 
# (results_df['bio.value'].str.contains('NH') == True) | 
# (results_df['bio.value'].str.contains('NJ') == True) | 
# (results_df['bio.value'].str.contains('NM') == True) | 
# (results_df['bio.value'].str.contains('NY') == True) | 
# (results_df['bio.value'].str.contains('NC') == True) | 
# (results_df['bio.value'].str.contains('ND') == True) | 
# (results_df['bio.value'].str.contains('OH') == True) | 
# (results_df['bio.value'].str.contains('OK') == True) | 
# (results_df['bio.value'].str.contains('OR') == True) | 
# (results_df['bio.value'].str.contains('PA') == True) | 
# (results_df['bio.value'].str.contains('RI') == True) | 
# (results_df['bio.value'].str.contains('SC') == True) | 
# (results_df['bio.value'].str.contains('SD') == True) | 
# (results_df['bio.value'].str.contains('TN') == True) | 
(results_df['bio.value'].str.contains('TX') == True) | 
(results_df['bio.value'].str.contains('T.X.') == True) | 
# (results_df['bio.value'].str.contains('UT') == True) | 
# (results_df['bio.value'].str.contains('VT') == True) | 
# (results_df['bio.value'].str.contains('VA') == True) | 
# (results_df['bio.value'].str.contains('WA') == True) | 
# (results_df['bio.value'].str.contains('WV') == True) | 
# (results_df['bio.value'].str.contains('WI') == True) | 
# (results_df['bio.value'].str.contains('WY') == True) | 
# (results_df['bio.value'].str.contains('DC') == True) | 
# (results_df['bio.value'].str.contains('GU') == True) | 
# (results_df['bio.value'].str.contains('MH') == True) | 
# (results_df['bio.value'].str.contains('MP') == True) | 
# (results_df['bio.value'].str.contains('PR') == True) | 
# (results_df['bio.value'].str.contains('VI') == True) | 
# (results_df['bio.value'].str.contains(' Ala.') == True) | 
# (results_df['bio.value'].str.contains(' Alaska') == True) | 
# (results_df['bio.value'].str.contains(' Ariz.') == True) | 
# (results_df['bio.value'].str.contains(' Ark.') == True) | 
# (results_df['bio.value'].str.contains(' Calif.') == True) | 
# (results_df['bio.value'].str.contains(' Color.') == True) | 
# (results_df['bio.value'].str.contains(' Conn.') == True) | 
# (results_df['bio.value'].str.contains(' Del.') == True) | 
# (results_df['bio.value'].str.contains(' Fla.') == True) | 
# (results_df['bio.value'].str.contains(' Ga.') == True) | 
# (results_df['bio.value'].str.contains(' Hawaii') == True) | 
# (results_df['bio.value'].str.contains(' Idaho') == True) | 
# (results_df['bio.value'].str.contains(' Ill.') == True) | 
# (results_df['bio.value'].str.contains(' Ind.') == True) | 
# (results_df['bio.value'].str.contains(' Iowa') == True) | 
# (results_df['bio.value'].str.contains(' Kan.') == True) | 
# (results_df['bio.value'].str.contains(' Ky.') == True) | 
# (results_df['bio.value'].str.contains(' La.') == True) | 
# (results_df['bio.value'].str.contains(' Maine') == True) | 
# (results_df['bio.value'].str.contains(' Md.') == True) | 
# (results_df['bio.value'].str.contains(' Mass.') == True) | 
# (results_df['bio.value'].str.contains(' Mich.') == True) | 
# (results_df['bio.value'].str.contains(' Minn.') == True) | 
# (results_df['bio.value'].str.contains(' Miss.') == True) | 
# (results_df['bio.value'].str.contains(' Mo.') == True) | 
# (results_df['bio.value'].str.contains(' Mont.') == True) | 
# (results_df['bio.value'].str.contains(' Neb.') == True) | 
# (results_df['bio.value'].str.contains(' Nev.') == True) | 
# (results_df['bio.value'].str.contains(' N.H.') == True) | 
# (results_df['bio.value'].str.contains(' N.J.') == True) | 
# (results_df['bio.value'].str.contains(' N.M.') == True) | 
# (results_df['bio.value'].str.contains(' N.Y.') == True) | 
# (results_df['bio.value'].str.contains(' N.C.') == True) | 
# (results_df['bio.value'].str.contains(' N.D.') == True) | 
# (results_df['bio.value'].str.contains(' Ohio') == True) | 
# (results_df['bio.value'].str.contains(' Okla.') == True) | 
# (results_df['bio.value'].str.contains(' Ore.') == True) | 
# (results_df['bio.value'].str.contains(' Pa.') == True) | 
# (results_df['bio.value'].str.contains(' R.I.') == True) | 
# (results_df['bio.value'].str.contains(' S.C.') == True) | 
# (results_df['bio.value'].str.contains(' S.Dak.') == True) | 
# (results_df['bio.value'].str.contains(' Tenn.') == True) | 
(results_df['bio.value'].str.contains(' Tex.') == True)  ]
# (results_df['bio.value'].str.contains(' Utah') == True) | 
# (results_df['bio.value'].str.contains(' V.T.') == True) | 
# (results_df['bio.value'].str.contains(' Va.') == True) | 
# (results_df['bio.value'].str.contains(' Wash.') == True) | 
# (results_df['bio.value'].str.contains(' W.Va.') == True) | 
# (results_df['bio.value'].str.contains(' Wis.') == True) | 
# (results_df['bio.value'].str.contains(' Wyo.') == True) | 
# (results_df['bio.value'].str.contains(' D.C.') == True) | 
# (results_df['bio.value'].str.contains(' Guam') == True) | 
# (results_df['bio.value'].str.contains(' M.I.') == True) | 
# (results_df['bio.value'].str.contains(' CNMI') == True) | 
# (results_df['bio.value'].str.contains(' P.R. or PUR') == True) | 
# (results_df['bio.value'].str.contains(' V.I.') == True) ]

# %%
results_df['test'] = results_df['bio.value'].str.extract(r'(?!BC|CE)(A-Z)')

# %%
results_df[(results_df['test'].notnull())]

# %%
results_df[(results_df['bio.value'].str.contains('Tex') == True)].head(2)

# %%
results_df.head()

# %%
no_upper['misspelledWord'].value_counts()

# %%
no_upper['misspelledWord'].iloc[26:27]

# %%
df_errors['test'] = df_errors['context'].astype(str).str.extract('([\s]+-[\s]+)')

# %%
df_errors[(df_errors['test'].notnull())].head(10)
